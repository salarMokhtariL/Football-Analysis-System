# %% [markdown]
# <a href="https://colab.research.google.com/github/salarMokhtariL/Football-Analysis-System/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Football Training Model
#
# > By Salar Mokhtari Laleh

# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# WARNING: Ignoring invalid distribution -hardet (/usr/local/lib/python3.10/dist-packages)
# ...
#   Using cached roboflow-1.1.28-py3-none-any.whl (74 kB)
# ...
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# ...
# WARNING: Ignoring invalid distribution -hardet (/usr/local/lib/python3.10/dist-packages)
# ...
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
# ...
# WARNING: Ignoring invalid distribution -hardet (/usr/local/lib/python3.10/dist-packages)
# ...
#   Using cached ultralytics-8.2.4-py3-none-any.whl (752 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="wzGDrsjT73gmwHC99x1k")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(8)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-8 in yolov5pytorch:: 100%|██████████| 522/522 [00:00<00:00, 832.09it/s]

# %%
import shutil

shutil.move('football-players-detection-8/train', 'football-players-detection-8/football-players-detection-8/train')
shutil.move('football-players-detection-8/test', 'football-players-detection-8/football-players-detection-8/test')
shutil.move('football-players-detection-8/valid', 'football-players-detection-8/football-players-detection-8/valid')
# Out:
# 'football-players-detection-8/football-players-detection-8/valid'

# %%
# !yolo task=detect mode=train model=yolov5s.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 17.7M/17.7M [00:00<00:00, 149MB/s]
# Ultralytics YOLOv8.2.4 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
